# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# ## RHIT

# %% [markdown]
# ### Reading In Raw PV files

# %% [markdown]
# #### First Month in Quarter

# %%
RHITFebF1H1 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm1_2024_02_H1.txt', sep='|')
RHITFebF1H1 = RHITFebF1H1.drop_duplicates('ClientStudentID')
RHITFebF1H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm1          ENU  461092116  \
# 150       AHIMA       RHIT  2023OctRHITForm1          ENU  461241735
# 300       AHIMA       RHIT  2023OctRHITForm1          ENU  461605872
# 450       AHIMA       RHIT  2023OctRHITForm1          ENU  461738755
# 600       AHIMA       RHIT  2023OctRHITForm1          ENU  463916439
#
#      ClientStudentID  ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2833907  2/6/2024        1   74    303  ...            0  \
# 150          1198696  2/3/2024        5   55    291  ...            0
# 300          2883512  2/3/2024        2   68    299  ...            0
# 450          2932239  2/8/2024        2   65    297  ...            0
# 600          2832495  2/2/2024        1   97    319  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITFebF2H1 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm2_2024_02_H1.txt', sep='|')
RHITFebF2H1 = RHITFebF2H1.drop_duplicates('ClientStudentID')
RHITFebF2H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm2          ENU  461744681  \
# 150       AHIMA       RHIT  2023OctRHITForm2          ENU  461772873
# 300       AHIMA       RHIT  2023OctRHITForm2          ENU  462045572
# 450       AHIMA       RHIT  2023OctRHITForm2          ENU  462296613
# 600       AHIMA       RHIT  2023OctRHITForm2          ENU  462865653
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            1194130   2/1/2024        2   73    302  ...            0  \
# 150          2707744  2/14/2024        1   67    298  ...            0
# 300          1407306  2/15/2024        2   67    298  ...            0
# 450          2952164  2/10/2024        1   43    283  ...            0
# 600          2885620   2/8/2024        1   76    304  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITFebF1H2 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm1_2024_02_H2.txt', sep='|')
RHITFebF1H2 = RHITFebF1H2.drop_duplicates('ClientStudentID')
RHITFebF1H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm1          ENU  462283795  \
# 150       AHIMA       RHIT  2023OctRHITForm1          ENU  462870788
# 300       AHIMA       RHIT  2023OctRHITForm1          ENU  462970806
# 450       AHIMA       RHIT  2023OctRHITForm1          ENU  463082601
# 600       AHIMA       RHIT  2023OctRHITForm1          ENU  463085617
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2574135  2/16/2024        2   78    306  ...            0  \
# 150          2731376  2/29/2024        1   89    313  ...            0
# 300          2852324  2/22/2024        2   65    297  ...            0
# 450          2885393  2/29/2024        4   79    306  ...            0
# 600          2914527  2/17/2024        1   96    318  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITFebF2H2 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm2_2024_02_H2.txt', sep='|')
RHITFebF2H2 = RHITFebF2H2.drop_duplicates('ClientStudentID')
RHITFebF2H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm2          ENU  462207943  \
# 150       AHIMA       RHIT  2023OctRHITForm2          ENU  462414925
# 300       AHIMA       RHIT  2023OctRHITForm2          ENU  463409858
# 450       AHIMA       RHIT  2023OctRHITForm2          ENU  463538656
# 600       AHIMA       RHIT  2023OctRHITForm2          ENU  463723031
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2914794  2/19/2024        1   54    290  ...            0  \
# 150          2904208  2/17/2024        1   93    315  ...            0
# 300          2354560  2/21/2024        1   65    297  ...            0
# 450          2885052  2/26/2024        1   60    294  ...            0
# 600          2902228  2/20/2024        1   54    290  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %% [markdown]
# #### Second Month in Quarter

# %%
RHITMarF1H1 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm1_2024_03_H1.txt', sep='|')
RHITMarF1H1 = RHITMarF1H1.drop_duplicates('ClientStudentID')
RHITMarF1H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm1          ENU  463153259  \
# 150       AHIMA       RHIT  2023OctRHITForm1          ENU  463445990
# 300       AHIMA       RHIT  2023OctRHITForm1          ENU  464193813
# 450       AHIMA       RHIT  2023OctRHITForm1          ENU  464791138
# 600       AHIMA       RHIT  2023OctRHITForm1          ENU  464852948
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2961311   3/2/2024        1   55    291  ...            0  \
# 150          2955213   3/5/2024        1   47    286  ...            0
# 300          2948863  3/15/2024        2   63    296  ...            0
# 450          2951915  3/11/2024        1   66    298  ...            0
# 600          2946894   3/1/2024        1   79    306  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITMarF2H1 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm2_2024_03_H1.txt', sep='|')
RHITMarF2H1 = RHITMarF2H1.drop_duplicates('ClientStudentID')
RHITMarF2H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm2          ENU  463470404  \
# 150       AHIMA       RHIT  2023OctRHITForm2          ENU  463948031
# 300       AHIMA       RHIT  2023OctRHITForm2          ENU  463955823
# 450       AHIMA       RHIT  2023OctRHITForm2          ENU  464227294
# 600       AHIMA       RHIT  2023OctRHITForm2          ENU  464290717
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2959821   3/1/2024        1   58    293  ...            0  \
# 150          2912815  3/11/2024        1   74    303  ...            0
# 300          2911666   3/5/2024        1   91    314  ...            0
# 450          2965102  3/12/2024        1   91    314  ...            0
# 600          2502969  3/13/2024        1   68    299  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITMarF1H2 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm1_2024_03_H2.txt', sep='|')
RHITMarF1H2 = RHITMarF1H2.drop_duplicates('ClientStudentID')
RHITMarF1H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm1          ENU  464582753  \
# 150       AHIMA       RHIT  2023OctRHITForm1          ENU  464977760
# 300       AHIMA       RHIT  2023OctRHITForm1          ENU  465665342
# 450       AHIMA       RHIT  2023OctRHITForm1          ENU  466839706
# 600       AHIMA       RHIT  2023OctRHITForm1          ENU  467492737
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2757709  3/18/2024        2   79    306  ...            0  \
# 150          2893508  3/19/2024        1  100    321  ...            0
# 300          2888849  3/27/2024        1   55    291  ...            0
# 450          2885210  3/22/2024        1   88    312  ...            0
# 600          2757115  3/27/2024        1   95    317  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITMarF2H2 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm2_2024_03_H2.txt', sep='|')
RHITMarF2H2 = RHITMarF2H2.drop_duplicates('ClientStudentID')
RHITMarF2H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm2          ENU  464253550  \
# 150       AHIMA       RHIT  2023OctRHITForm2          ENU  464999520
# 300       AHIMA       RHIT  2023OctRHITForm2          ENU  466194562
# 450       AHIMA       RHIT  2023OctRHITForm2          ENU  467304539
# 600       AHIMA       RHIT  2023OctRHITForm2          ENU  467683087
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2851918  3/16/2024        1   86    311  ...            0  \
# 150          2843840  3/21/2024        1   60    294  ...            0
# 300          2946940  3/19/2024        1   61    295  ...            0
# 450          1880602  3/23/2024        4   70    300  ...            0
# 600          2936092  3/28/2024        1   64    297  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %% [markdown]
# #### Third Month in Quarter

# %%
RHITAprF1H1 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm1_2024_04_H1.txt', sep='|')
RHITAprF1H1 = RHITAprF1H1.drop_duplicates('ClientStudentID')
RHITAprF1H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm1          ENU  466908185  \
# 150       AHIMA       RHIT  2023OctRHITForm1          ENU  467690044
# 300       AHIMA       RHIT  2023OctRHITForm1          ENU  467756515
# 450       AHIMA       RHIT  2023OctRHITForm1          ENU  467944333
# 600       AHIMA       RHIT  2023OctRHITForm1          ENU  468663576
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2919981  4/12/2024        1   50    288  ...            0  \
# 150          2966708   4/6/2024        1   89    313  ...            0
# 300          2798763  4/11/2024        1   86    311  ...            0
# 450          2664435  4/15/2024        1  104    324  ...            0
# 600          2846309  4/10/2024        1   76    304  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITAprF2H1 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm2_2024_04_H1.txt', sep='|')
RHITAprF2H1 = RHITAprF2H1.drop_duplicates('ClientStudentID')
RHITAprF2H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm2          ENU  468222674  \
# 150       AHIMA       RHIT  2023OctRHITForm2          ENU  468842379
# 300       AHIMA       RHIT  2023OctRHITForm2          ENU  470696107
# 450       AHIMA       RHIT  2023OctRHITForm2          ENU  470809752
# 600       AHIMA       RHIT  2023OctRHITForm2          ENU  470838183
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2915475   4/3/2024        1   85    310  ...            0  \
# 150          2935083  4/13/2024        1   83    309  ...            0
# 300          2785444  4/14/2024        1   61    295  ...            0
# 450          2913237   4/4/2024        1   69    300  ...            0
# 600          2913366   4/1/2024        1   62    295  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITAprF1H2 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm1_2024_04_H2.txt', sep='|')
RHITAprF1H2 = RHITAprF1H2.drop_duplicates('ClientStudentID')
RHITAprF1H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm1          ENU  467246972  \
# 150       AHIMA       RHIT  2023OctRHITForm1          ENU  467699223
# 300       AHIMA       RHIT  2023OctRHITForm1          ENU  468124370
# 450       AHIMA       RHIT  2023OctRHITForm1          ENU  468567011
# 600       AHIMA       RHIT  2023OctRHITForm1          ENU  469648001
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2882270  4/27/2024        1   58    293  ...            0  \
# 150          2947580  4/30/2024        1   79    306  ...            0
# 300          2963755  4/17/2024        1   80    307  ...            0
# 450          2958620  4/23/2024        1   51    288  ...            0
# 600          2945954  4/25/2024        1   87    311  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %%
RHITAprF2H2 = pd.read_csv('AHIMA_RHIT_2023OctRHITForm2_2024_04_H2.txt', sep='|')
RHITAprF2H2 = RHITAprF2H2.drop_duplicates('ClientStudentID')
RHITAprF2H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIT  2023OctRHITForm2          ENU  467367172  \
# 150       AHIMA       RHIT  2023OctRHITForm2          ENU  472011006
# 300       AHIMA       RHIT  2023OctRHITForm2          ENU  472016155
# 450       AHIMA       RHIT  2023OctRHITForm2          ENU  472102790
# 600       AHIMA       RHIT  2023OctRHITForm2          ENU  472310218
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 0            2912767  4/25/2024        1   66    298  ...            0  \
# 150          2946733  4/27/2024        1   99    320  ...            0
# 300          2879709  4/20/2024        2   71    301  ...            0
# 450          2912293  4/28/2024        1  105    325  ...            0
# 600          2895613  4/23/2024        1   94    316  ...            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3  Blueprint-4
# ...

# %% [markdown]
# #### Combining

# %%
RHIT = pd.concat([RHITFebF1H1,RHITFebF2H1,RHITFebF1H2,RHITFebF2H2,RHITMarF1H1,RHITMarF2H1,RHITMarF1H2,RHITMarF2H2,RHITAprF1H1,RHITAprF2H1,RHITAprF1H2,RHITAprF2H2]).sort_values(by=['ExamDate'])
RHIT.head()
# Out:
#      ClientsCode ExamSeries              Form LanguageCode      RegID
# 750        AHIMA       RHIT  2023OctRHITForm2          ENU  462987819  \
# 0          AHIMA       RHIT  2023OctRHITForm2          ENU  461744681
# 3300       AHIMA       RHIT  2023OctRHITForm2          ENU  468850933
# 1950       AHIMA       RHIT  2023OctRHITForm2          ENU  467569565
# 4200       AHIMA       RHIT  2023OctRHITForm1          ENU  469872839
#
#       ClientStudentID   ExamDate  Attempt  Raw  Score  ... ReviewTimeMS
# 750           2886716   2/1/2024        1   62    295  ...            0  \
# 0             1194130   2/1/2024        2   73    302  ...            0
# 3300          2996856   2/1/2024        1   82    308  ...            0
# 1950          2970675  2/10/2024        1   72    301  ...            0
# 4200          2928415  2/10/2024        1   91    314  ...            0
#
#      TotalTimeMS       Domain Blueprint-1 Blueprint-2 Blueprint-3
# ...

# %%
RHIT = RHIT[['ClientStudentID','Form','Attempt','Grade','ExamDate','Blueprint-1','Blueprint-2','Blueprint-3','Blueprint-4','Blueprint-5','Blueprint-6','Score']]
RHIT.head()
# Out:
#       ClientStudentID              Form  Attempt Grade   ExamDate
# 750           2886716  2023OctRHITForm2        1  fail   2/1/2024  \
# 0             1194130  2023OctRHITForm2        2  pass   2/1/2024
# 3300          2996856  2023OctRHITForm2        1  pass   2/1/2024
# 1950          2970675  2023OctRHITForm2        1  pass  2/10/2024
# 4200          2928415  2023OctRHITForm1        1  pass  2/10/2024
#
#       Blueprint-1  Blueprint-2  Blueprint-3  Blueprint-4  Blueprint-5
# 750            56           29           50           50           41  \
# 0              67           52           45           59           65
# 3300           67           67           60           72           53
# 1950           70           43           55           59           65
# 4200           80           76           73           67           65
#
#       Blueprint-6  Score
# 750            62    295
# 0              38    302
# 3300           46    308
# 1950           23    301
# ...

# %%
RHIT = RHIT.rename(columns={'Attempt':'Attempt Number','Grade':'Status','ExamDate':'Exam Date','Blueprint-1':'Domain 1','Blueprint-2':'Domain 2','Blueprint-3':'Domain 3','Blueprint-4':'Domain 4','Blueprint-5':'Domain 5','Blueprint-6':'Domain 6','Score':'Scale Score'})
RHIT.head()
# Out:
#       ClientStudentID              Form  Attempt Number Status  Exam Date
# 750           2886716  2023OctRHITForm2               1   fail   2/1/2024  \
# 0             1194130  2023OctRHITForm2               2   pass   2/1/2024
# 3300          2996856  2023OctRHITForm2               1   pass   2/1/2024
# 1950          2970675  2023OctRHITForm2               1   pass  2/10/2024
# 4200          2928415  2023OctRHITForm1               1   pass  2/10/2024
#
#       Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Domain 6  Scale Score
# 750         56        29        50        50        41        62          295
# 0           67        52        45        59        65        38          302
# 3300        67        67        60        72        53        46          308
# 1950        70        43        55        59        65        23          301
# 4200        80        76        73        67        65        53          314

# %%
RHIT.to_csv('RHITQtr2Data23-24.csv')

# %% [markdown]
# ## RHIA

# %% [markdown]
# ### Reading in Raw PV Data, cleaning and combining

# %% [markdown]
# #### First Month in Quarter

# %%
RHIAFebF1H1 = pd.read_csv('AHIMA_RHIA_RHIA2023Form1_2024_02_H1.txt', sep='|')
RHIAFebF1H1 = RHIAFebF1H1.drop_duplicates('ClientStudentID')
RHIAFebF1H1.head()
# Out:
#     ClientsCode ExamSeries           Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIA2023Form1          ENU  461732055  \
# 150       AHIMA       RHIA  RHIA2023Form1          ENU  461773700
# 300       AHIMA       RHIA  RHIA2023Form1          ENU  461847603
# 450       AHIMA       RHIA  RHIA2023Form1          ENU  461934717
# 600       AHIMA       RHIA  RHIA2023Form1          ENU  462398144
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0            2709154  2/10/2024        2   74    291  ...   23988  \
# 150          1194766   2/3/2024        1   85    301  ...   20390
# 300          2412652   2/3/2024        5   76    293  ...  115302
# 450          2953646  2/13/2024        1   94    310  ...   63033
# 600          2783261  2/13/2024        1   93    309  ...  135871
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0       23988  Blueprint-1          50          65  \
# ...

# %%
RHIANovF2H1 = pd.read_csv('AHIMA_RHIA_RHIA2023PilotFinal_2023_11_H2.txt', sep='|')
RHIANovF2H1 = RHIANovF2H1.drop_duplicates('ClientStudentID')
RHIANovF2H1.head()
# Out:
#     ClientsCode ExamSeries                Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIA2023PilotFinal          ENU  455617577  \
# 150       AHIMA       RHIA  RHIA2023PilotFinal          ENU  456156480
# 300       AHIMA       RHIA  RHIA2023PilotFinal          ENU  456164242
# 450       AHIMA       RHIA  RHIA2023PilotFinal          ENU  456443937
# 600       AHIMA       RHIA  RHIA2023PilotFinal          ENU  456512838
#
#      ClientStudentID    ExamDate  Attempt  Raw  Score  ... TimeMS
# 0            2704644  11/20/2023        1   82     82  ...  37783  \
# 150          2960016  11/20/2023        1   67     67  ...  99212
# 300          2773116  11/30/2023        3   71     71  ...  77826
# 450          2915001  11/19/2023        1   42     42  ...  54176
# 600          2928086  11/30/2023        2   73     73  ...  49585
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0       37783  Blueprint-1          74          60  \
# ...

# %%
RHIAFebF1H2 = pd.read_csv('AHIMA_RHIA_RHIA2023Form1_2024_02_H2.txt', sep='|')
RHIAFebF1H2 = RHIAFebF1H2.drop_duplicates('ClientStudentID')
RHIAFebF1H2.head()
# Out:
#     ClientsCode ExamSeries           Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIA2023Form1          ENU  462287063  \
# 150       AHIMA       RHIA  RHIA2023Form1          ENU  462778448
# 300       AHIMA       RHIA  RHIA2023Form1          ENU  462889289
# 450       AHIMA       RHIA  RHIA2023Form1          ENU  462963398
# 600       AHIMA       RHIA  RHIA2023Form1          ENU  463038907
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0            2904453  2/22/2024        2   60    279  ...   25661  \
# 150          1168795  2/22/2024        1   86    302  ...   16015
# 300          2907780  2/24/2024        2   70    288  ...  210379
# 450          1993082  2/28/2024        1   95    311  ...   46422
# 600          2984037  2/19/2024        1   88    304  ...   95160
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0       25661  Blueprint-1          50          35  \
# ...

# %%
RHIAAugF2H2 = pd.read_csv('AHIMA_RHIA_Form2_2023_08_H2.txt', sep='|')
RHIAAugF2H2 = RHIAAugF2H2.drop_duplicates('ClientStudentID')
RHIAAugF2H2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 RHIAAugF2H2 = pd.read_csv('AHIMA_RHIA_Form2_2023_08_H2.txt', sep='|')
#       2 RHIAAugF2H2 = RHIAAugF2H2.drop_duplicates('ClientStudentID')
#       3 RHIAAugF2H2.head()
#
# ...

# %% [markdown]
# #### Second Month in Quarter

# %%
RHIAMarF1H1 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form1_2024_03_H1.txt', sep='|')
RHIAMarF1H1 = RHIAMarF1H1.drop_duplicates('ClientStudentID')
RHIAMarF1H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form1          ENU  463570810  \
# 150       AHIMA       RHIA  RHIAMAR2024Form1          ENU  465476143
# 300       AHIMA       RHIA  RHIAMAR2024Form1          ENU  466039435
# 450       AHIMA       RHIA  RHIAMAR2024Form1          ENU  466314247
# 600       AHIMA       RHIA  RHIAMAR2024Form1          ENU  467747455
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0            2914039   3/6/2024        1  101    318  ...   36896  \
# 150          2495059   3/6/2024        3   96    313  ...   32509
# 300          2908606   3/1/2024        1   98    315  ...   91106
# 450          2459720  3/15/2024        6   72    289  ...   23492
# 600          2902064   3/1/2024        1   91    307  ...  270959
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0       36896  Blueprint-1          92          80  \
# ...

# %%
RHIAMarF2H1 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form2_2024_03_H1.txt', sep='|')
RHIAMarF2H1 = RHIAMarF2H1.drop_duplicates('ClientStudentID')
RHIAMarF2H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form2          ENU  463062776  \
# 150       AHIMA       RHIA  RHIAMAR2024Form2          ENU  464090070
# 300       AHIMA       RHIA  RHIAMAR2024Form2          ENU  464567885
# 450       AHIMA       RHIA  RHIAMAR2024Form2          ENU  466462438
# 600       AHIMA       RHIA  RHIAMAR2024Form2          ENU  468309645
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0            2975590   3/1/2024        1  100    316  ...  148224  \
# 150          2174526   3/1/2024        1  102    318  ...  137427
# 300          2960423   3/2/2024        1   96    312  ...   37260
# 450          2881805   3/1/2024        2   82    299  ...   61215
# 600          2913906  3/11/2024        1  101    317  ...   24132
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0      148224  Blueprint-1          87          75  \
# ...

# %%
RHIAMarF1H2 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form1_2024_03_H2.txt', sep='|')
RHIAMarF1H2 = RHIAMarF1H2.drop_duplicates('ClientStudentID')
RHIAMarF1H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form1          ENU  465880783  \
# 150       AHIMA       RHIA  RHIAMAR2024Form1          ENU  466117412
# 300       AHIMA       RHIA  RHIAMAR2024Form1          ENU  466422010
# 450       AHIMA       RHIA  RHIAMAR2024Form1          ENU  467504815
# 600       AHIMA       RHIA  RHIAMAR2024Form1          ENU  467609721
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0             465310  3/25/2024        1  106    324  ...   64013  \
# 150          2591141  3/28/2024        2   81    298  ...   24108
# 300          2897599  3/27/2024        1  102    319  ...  100548
# 450          2838783  3/20/2024        1   98    315  ...  191805
# 600          2884632  3/27/2024        1  102    319  ...   11760
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0       64013  Blueprint-1          79          70  \
# ...

# %%
RHIAMarF2H2 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form2_2024_03_H2.txt', sep='|')
RHIAMarF2H2 = RHIAMarF2H2.drop_duplicates('ClientStudentID')
RHIAMarF2H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form2          ENU  464857662  \
# 150       AHIMA       RHIA  RHIAMAR2024Form2          ENU  467197789
# 300       AHIMA       RHIA  RHIAMAR2024Form2          ENU  467199567
# 450       AHIMA       RHIA  RHIAMAR2024Form2          ENU  467257751
# 600       AHIMA       RHIA  RHIAMAR2024Form2          ENU  468672025
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... TimeMS ReviewTimeMS
# 0            2396435  3/19/2024        1   84    301  ...  75371            0  \
# 150          2773541  3/30/2024        2   94    310  ...  32450            0
# 300          2842162  3/23/2024        1   76    294  ...  71701            0
# 450          2891436  3/18/2024        3   87    303  ...  35145            0
# 600          2719953  3/25/2024        2   88    304  ...  24841            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2  Blueprint-3 Blueprint-4
# ...

# %% [markdown]
# #### Third Month in Quarter

# %%
RHIAAprF1H1 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form1_2024_04_H1.txt', sep='|')
RHIAAprF1H1 = RHIAAprF1H1.drop_duplicates('ClientStudentID')
RHIAAprF1H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form1          ENU  466212968  \
# 150       AHIMA       RHIA  RHIAMAR2024Form1          ENU  467120738
# 300       AHIMA       RHIA  RHIAMAR2024Form1          ENU  468244690
# 450       AHIMA       RHIA  RHIAMAR2024Form1          ENU  468282600
# 600       AHIMA       RHIA  RHIAMAR2024Form1          ENU  468338629
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0            2843008  4/11/2024        2   68    286  ...   66764  \
# 150          2920665   4/8/2024        2   86    302  ...  102476
# 300          2971801   4/6/2024        1   86    302  ...   24995
# 450          2705039  4/13/2024        1   81    298  ...   21765
# 600          2950462   4/8/2024        1  104    322  ...   23791
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0       66764  Blueprint-1          67          55  \
# ...

# %%
RHIAAprF2H1 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form2_2024_04_H1.txt', sep='|')
RHIAAprF2H1 = RHIAAprF2H1.drop_duplicates('ClientStudentID')
RHIAAprF2H1.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form2          ENU  466130677  \
# 150       AHIMA       RHIA  RHIAMAR2024Form2          ENU  466507912
# 300       AHIMA       RHIA  RHIAMAR2024Form2          ENU  468031913
# 450       AHIMA       RHIA  RHIAMAR2024Form2          ENU  468670377
# 600       AHIMA       RHIA  RHIAMAR2024Form2          ENU  468840947
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... TimeMS ReviewTimeMS
# 0            2845034   4/9/2024        2   89    305  ...  21792            0  \
# 150          2995642   4/6/2024        1   78    296  ...   7157            0
# 300          2816612  4/11/2024        3   91    307  ...  43658            0
# 450          2948758   4/3/2024        1   87    303  ...  67325            0
# 600          2947826   4/8/2024        1  103    319  ...  27738            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2  Blueprint-3 Blueprint-4
# ...

# %%
RHIAAprF1H2 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form1_2024_04_H2.txt', sep='|')
RHIAAprF1H2 = RHIAAprF1H2.drop_duplicates('ClientStudentID')
RHIAAprF1H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form1          ENU  468546612  \
# 150       AHIMA       RHIA  RHIAMAR2024Form1          ENU  468651777
# 300       AHIMA       RHIA  RHIAMAR2024Form1          ENU  468770808
# 450       AHIMA       RHIA  RHIAMAR2024Form1          ENU  468842550
# 600       AHIMA       RHIA  RHIAMAR2024Form1          ENU  469069719
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ... TimeMS ReviewTimeMS
# 0            2817294  4/27/2024        1   90    306  ...  25354            0  \
# 150          2909805  4/26/2024        1   82    299  ...  23208            0
# 300          1924188  4/23/2024        1   89    305  ...  21845            0
# 450          1130498  4/20/2024        1   72    289  ...  27106            0
# 600          2990681  4/26/2024        1  108    327  ...  28279            0
#
#     TotalTimeMS       Domain Blueprint-1 Blueprint-2  Blueprint-3 Blueprint-4
# ...

# %%
RHIAAprF2H2 = pd.read_csv('AHIMA_RHIA_RHIAMAR2024Form2_2024_04_H2.txt', sep='|')
RHIAAprF2H2 = RHIAAprF2H2.drop_duplicates('ClientStudentID')
RHIAAprF2H2.head()
# Out:
#     ClientsCode ExamSeries              Form LanguageCode      RegID
# 0         AHIMA       RHIA  RHIAMAR2024Form2          ENU  467488686  \
# 150       AHIMA       RHIA  RHIAMAR2024Form2          ENU  467769683
# 300       AHIMA       RHIA  RHIAMAR2024Form2          ENU  469559165
# 450       AHIMA       RHIA  RHIAMAR2024Form2          ENU  471752516
# 600       AHIMA       RHIA  RHIAMAR2024Form2          ENU  471807126
#
#      ClientStudentID   ExamDate  Attempt  Raw  Score  ...  TimeMS
# 0            2813942  4/23/2024        2   77    295  ...  159561  \
# 150          2845499  4/24/2024        1   66    286  ...  117727
# 300          2915988  4/25/2024        1   92    308  ...   39679
# 450          2948726  4/19/2024        1   88    304  ...   13121
# 600          2948455  4/17/2024        1   93    309  ...   47638
#
#     ReviewTimeMS TotalTimeMS       Domain Blueprint-1 Blueprint-2
# 0              0      159561  Blueprint-1          48          80  \
# ...

# %% [markdown]
# #### Combining

# %%
RHIA = pd.concat([RHIAFebF1H1,RHIAFebF1H2,RHIAMarF1H1,RHIAMarF2H1,RHIAMarF1H2,RHIAMarF2H2,RHIAAprF1H1,RHIAAprF2H1,RHIAAprF1H2,RHIAAprF2H2]).sort_values(by=['ExamDate'],ascending=False)
RHIA.head()
# Out:
#      ClientsCode ExamSeries              Form LanguageCode      RegID
# 0          AHIMA       RHIA  RHIAMAR2024Form2          ENU  466130677  \
# 3750       AHIMA       RHIA  RHIAMAR2024Form2          ENU  471858519
# 3450       AHIMA       RHIA  RHIAMAR2024Form2          ENU  474703019
# 2250       AHIMA       RHIA  RHIAMAR2024Form1          ENU  472076869
# 2850       AHIMA       RHIA  RHIAMAR2024Form2          ENU  473730578
#
#       ClientStudentID  ExamDate  Attempt  Raw  Score  ... TimeMS ReviewTimeMS
# 0             2845034  4/9/2024        2   89    305  ...  21792            0  \
# 3750          2948153  4/9/2024        1   92    308  ...  57878            0
# 3450          2953958  4/9/2024        1  102    318  ...  27507            0
# 2250          2847686  4/8/2024        1   94    310  ...  76491            0
# 2850          2883451  4/8/2024        1   86    302  ...  86808            0
#
#      TotalTimeMS       Domain Blueprint-1 Blueprint-2  Blueprint-3
# ...

# %%
RHIA = RHIA[['ClientStudentID','Form','Attempt','Grade','ExamDate','Blueprint-1','Blueprint-2','Blueprint-3','Blueprint-4','Blueprint-5','Score']]
RHIA.head()
# Out:
#       ClientStudentID              Form  Attempt Grade  ExamDate  Blueprint-1
# 0             2845034  RHIAMAR2024Form2        2  pass  4/9/2024           70  \
# 3750          2948153  RHIAMAR2024Form2        1  pass  4/9/2024           57
# 3450          2953958  RHIAMAR2024Form2        1  pass  4/9/2024           78
# 2250          2847686  RHIAMAR2024Form1        1  pass  4/8/2024           79
# 2850          2883451  RHIAMAR2024Form2        1  pass  4/8/2024           74
#
#       Blueprint-2  Blueprint-3  Blueprint-4  Blueprint-5  Score
# 0              70           70           73           61    305
# 3750           80           77           73           68    308
# 3450           75           80           73           84    318
# 2250           95           67           65           63    310
# 2850           70           67           69           55    302

# %%
#Keithsinstructions = RHIA[['RegID','ClientStudentID','Form','ExamDate','Attempt','Raw','Score','Blueprint-1','Blueprint-2','Blueprint-3','Blueprint-4','Blueprint-5']]
#Keithsinstructions.head()

# %%
RHIA = RHIA.rename(columns={'ClientStudentID': 'AHIMA ID','Attempt':'Attempt Number','Grade':'Status','ExamDate':'Exam Date','Blueprint-1':'Domain 1','Blueprint-2':'Domain 2','Blueprint-3':'Domain 3','Blueprint-4':'Domain 4','Blueprint-5':'Domain 5','Score':'Scale Score'})
RHIA.head()
# Out:
#       AHIMA ID              Form  Attempt Number Status Exam Date  Domain 1
# 0      2845034  RHIAMAR2024Form2               2   pass  4/9/2024        70  \
# 3750   2948153  RHIAMAR2024Form2               1   pass  4/9/2024        57
# 3450   2953958  RHIAMAR2024Form2               1   pass  4/9/2024        78
# 2250   2847686  RHIAMAR2024Form1               1   pass  4/8/2024        79
# 2850   2883451  RHIAMAR2024Form2               1   pass  4/8/2024        74
#
#       Domain 2  Domain 3  Domain 4  Domain 5  Scale Score
# 0           70        70        73        61          305
# 3750        80        77        73        68          308
# 3450        75        80        73        84          318
# 2250        95        67        65        63          310
# 2850        70        67        69        55          302

# %%
RHIA.to_csv('RHIA_Qtr3_2324_Data.csv')

# %% [markdown]
# ## School Data

# %%
RHIT_Scores = RHIT.rename(columns={'ClientStudentID': 'AHIMA ID'})
RHIT_Scores.head()
# Out:
#       AHIMA ID              Form  Attempt Number Status  Exam Date  Domain 1
# 750    2886716  2023OctRHITForm2               1   fail   2/1/2024        56  \
# 0      1194130  2023OctRHITForm2               2   pass   2/1/2024        67
# 3300   2996856  2023OctRHITForm2               1   pass   2/1/2024        67
# 1950   2970675  2023OctRHITForm2               1   pass  2/10/2024        70
# 4200   2928415  2023OctRHITForm1               1   pass  2/10/2024        80
#
#       Domain 2  Domain 3  Domain 4  Domain 5  Domain 6  Scale Score
# 750         29        50        50        41        62          295
# 0           52        45        59        65        38          302
# 3300        67        60        72        53        46          308
# 1950        43        55        59        65        23          301
# 4200        76        73        67        65        53          314

# %%
RHIT_Scores.shape
# Out:
# (448, 12)

# %%
RHIA_Scores = RHIA.rename(columns={'ClientStudentID': 'AHIMA ID'})
RHIA_Scores.head()
# Out:
#       AHIMA ID              Form  Attempt Number Status Exam Date  Domain 1
# 0      2845034  RHIAMAR2024Form2               2   pass  4/9/2024        70  \
# 3750   2948153  RHIAMAR2024Form2               1   pass  4/9/2024        57
# 3450   2953958  RHIAMAR2024Form2               1   pass  4/9/2024        78
# 2250   2847686  RHIAMAR2024Form1               1   pass  4/8/2024        79
# 2850   2883451  RHIAMAR2024Form2               1   pass  4/8/2024        74
#
#       Domain 2  Domain 3  Domain 4  Domain 5  Scale Score
# 0           70        70        73        61          305
# 3750        80        77        73        68          308
# 3450        75        80        73        84          318
# 2250        95        67        65        63          310
# 2850        70        67        69        55          302

# %%
RHIA_Scores.shape
# Out:
# (256, 11)

# %%
RHIT_Schools = pd.read_excel('2023-2024 Q3 RHIT Schools.xlsx')
RHIT_Schools.head()
# Out:
#        ID  AHIMA ID   Applicant's Name      Exam Pass Date Certification
# 0  294966   1194130  Ingrid Millington 2024-02-01 09:00:15          RHIT  \
# 1  294819   2886716   Angela Stockling 2024-02-01 09:40:43          RHIT
# 2  296745   2996856       Dawn Grzejka 2024-02-01 12:31:00          RHIT
# 3  297965   2978911       Bethany Meng 2024-02-02 07:55:37          RHIT
# 4  293962   2832495      Andrea Beaver 2024-02-02 08:14:50          RHIT
#
#   Status EPC Code                                   School Name
# 0   Pass    HA670  Devry University - Online Campus HIT Program  \
# 1   Fail    HA726                            Saint Paul College
# 2   Pass    HA747       Rasmussen University - Online Associate
# 3   Fail      817                   Formerly Accredited Program
# 4   Pass    HA659                       Anoka Technical College
#
#   Graduation Date  School Notifications
# 0      2011-10-23                     0
# 1      2022-07-29                     1
# ...

# %%
RHIT_Schools.shape
# Out:
# (438, 10)

# %%
RHIA_Schools = pd.read_excel('2023-2024 Q3 RHIA Schools.xlsx')
RHIA_Schools.head()
# Out:
#        ID  AHIMA ID Applicant's Name      Exam Pass Date Certification Status
# 0  294345   2885867   Eliza Sandoval 2024-02-01 07:38:26          RHIA   Fail  \
# 1  293406   1196549   Christina Ball 2024-02-01 08:41:23          RHIA   Pass
# 2  295548   2927718   Ansley Blanton 2024-02-02 07:05:30          RHIA   Pass
# 3  295198   2412652    Debbie Hodges 2024-02-03 08:16:49          RHIA   Fail
# 4  298586   1766547       Robert Lam 2024-02-03 08:22:47          RHIA   Pass
#
#   EPC Code                                        School Name Graduation Date
# 0    HB132  University of Washington Health Informatics an...      2022-06-10  \
# 1    HB152                       Western Governors University      2022-09-14
# 2    HB086                           East Carolina University      2022-05-06
# 3    HB086                           East Carolina University      2007-05-05
# 4    HM015                           Slippery Rock University      2023-05-06
#
#    School Notifications
# ...

# %%
RHIA_Schools.shape
# Out:
# (254, 10)

# %% [markdown]
# #### Merging Aptify & Pearson Data (RHIT)

# %%
RHIT_School_Scores = pd.merge(RHIT_Scores,RHIT_Schools, on='AHIMA ID', how='left')
RHIT_School_Scores.head()
# Out:
#    AHIMA ID              Form  Attempt Number Status_x  Exam Date  Domain 1
# 0   2886716  2023OctRHITForm2               1     fail   2/1/2024        56  \
# 1   1194130  2023OctRHITForm2               2     pass   2/1/2024        67
# 2   2996856  2023OctRHITForm2               1     pass   2/1/2024        67
# 3   2970675  2023OctRHITForm2               1     pass  2/10/2024        70
# 4   2928415  2023OctRHITForm1               1     pass  2/10/2024        80
#
#    Domain 2  Domain 3  Domain 4  Domain 5  ...  Scale Score        ID
# 0        29        50        50        41  ...          295  294819.0  \
# 1        52        45        59        65  ...          302  294966.0
# 2        67        60        72        53  ...          308  296745.0
# 3        43        55        59        65  ...          301  297551.0
# 4        76        73        67        65  ...          314  293325.0
#
#     Applicant's Name      Exam Pass Date Certification Status_y EPC Code
# ...

# %%
RHIT_School_Scores['Total']=np.nan
RHIT_School_Scores.head()
# Out:
#    AHIMA ID              Form  Attempt Number Status_x  Exam Date  Domain 1
# 0   2886716  2023OctRHITForm2               1     fail   2/1/2024        56  \
# 1   1194130  2023OctRHITForm2               2     pass   2/1/2024        67
# 2   2996856  2023OctRHITForm2               1     pass   2/1/2024        67
# 3   2970675  2023OctRHITForm2               1     pass  2/10/2024        70
# 4   2928415  2023OctRHITForm1               1     pass  2/10/2024        80
#
#    Domain 2  Domain 3  Domain 4  Domain 5  ...        ID   Applicant's Name
# 0        29        50        50        41  ...  294819.0   Angela Stockling  \
# 1        52        45        59        65  ...  294966.0  Ingrid Millington
# 2        67        60        72        53  ...  296745.0       Dawn Grzejka
# 3        43        55        59        65  ...  297551.0   Michelle Emerson
# 4        76        73        67        65  ...  293325.0    rafaela vantasi
#
# ...

# %%
RHIT_School_Scores = RHIT_School_Scores[["Applicant's Name",'Attempt Number','Status_y','Exam Date','Graduation Date','Total','Domain 1','Domain 2','Domain 3','Domain 4','Domain 5','Domain 6','Scale Score','EPC Code','School Name','School Notifications']]
RHIT_School_Scores.head()
# Out:
#     Applicant's Name  Attempt Number Status_y  Exam Date Graduation Date
# 0   Angela Stockling               1     Fail   2/1/2024      2022-07-29  \
# 1  Ingrid Millington               2     Pass   2/1/2024      2011-10-23
# 2       Dawn Grzejka               1     Pass   2/1/2024      2015-06-21
# 3   Michelle Emerson               1     Pass  2/10/2024      2023-05-01
# 4    rafaela vantasi               1     Pass  2/10/2024      2023-05-31
#
#    Total  Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Domain 6
# 0    NaN        56        29        50        50        41        62  \
# 1    NaN        67        52        45        59        65        38
# 2    NaN        67        67        60        72        53        46
# 3    NaN        70        43        55        59        65        23
# 4    NaN        80        76        73        67        65        53
#
#    Scale Score EPC Code                                   School Name
# ...

# %%
RHIT_School_Scores = RHIT_School_Scores.rename(columns={'Status_y':'Status',})
RHIT_School_Scores.head()
# Out:
#     Applicant's Name  Attempt Number Status  Exam Date Graduation Date  Total
# 0   Angela Stockling               1   Fail   2/1/2024      2022-07-29    NaN  \
# 1  Ingrid Millington               2   Pass   2/1/2024      2011-10-23    NaN
# 2       Dawn Grzejka               1   Pass   2/1/2024      2015-06-21    NaN
# 3   Michelle Emerson               1   Pass  2/10/2024      2023-05-01    NaN
# 4    rafaela vantasi               1   Pass  2/10/2024      2023-05-31    NaN
#
#    Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Domain 6  Scale Score
# 0        56        29        50        50        41        62          295  \
# 1        67        52        45        59        65        38          302
# 2        67        67        60        72        53        46          308
# 3        70        43        55        59        65        23          301
# 4        80        76        73        67        65        53          314
#
# ...

# %%
RHIT_School_Scores.shape
# Out:
# (450, 16)

# %%
RHIT_School_Scores["Applicant's Name"] = RHIT_School_Scores["Applicant's Name"].str.title()
RHIT_School_Scores.head()
# Out:
#     Applicant's Name  Attempt Number Status  Exam Date Graduation Date  Total
# 0   Angela Stockling               1   Fail   2/1/2024      2022-07-29    NaN  \
# 1  Ingrid Millington               2   Pass   2/1/2024      2011-10-23    NaN
# 2       Dawn Grzejka               1   Pass   2/1/2024      2015-06-21    NaN
# 3   Michelle Emerson               1   Pass  2/10/2024      2023-05-01    NaN
# 4    Rafaela Vantasi               1   Pass  2/10/2024      2023-05-31    NaN
#
#    Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Domain 6  Scale Score
# 0        56        29        50        50        41        62          295  \
# 1        67        52        45        59        65        38          302
# 2        67        67        60        72        53        46          308
# 3        70        43        55        59        65        23          301
# 4        80        76        73        67        65        53          314
#
# ...

# %%
RHIT_School_Scores['Status'] = RHIT_School_Scores['Status'].str.title()
RHIT_School_Scores.head()
# Out:
#     Applicant's Name  Attempt Number Status  Exam Date Graduation Date  Total
# 0   Angela Stockling               1   Fail   2/1/2024      2022-07-29    NaN  \
# 1  Ingrid Millington               2   Pass   2/1/2024      2011-10-23    NaN
# 2       Dawn Grzejka               1   Pass   2/1/2024      2015-06-21    NaN
# 3   Michelle Emerson               1   Pass  2/10/2024      2023-05-01    NaN
# 4    Rafaela Vantasi               1   Pass  2/10/2024      2023-05-31    NaN
#
#    Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Domain 6  Scale Score
# 0        56        29        50        50        41        62          295  \
# 1        67        52        45        59        65        38          302
# 2        67        67        60        72        53        46          308
# 3        70        43        55        59        65        23          301
# 4        80        76        73        67        65        53          314
#
# ...

# %%
RHIT_School_Scores.to_csv('RHIT23-24 Q3.csv')

# %%
groups = RHIT_School_Scores.groupby('EPC Code')


    #print('Group Name:', group_name)
    #print(group_df.head())    
with pd.ExcelWriter('RHIT_School_Score_Report_Qtr3_2023-2024.xlsx') as writer:
    for group_name, group_df in groups:
        group_df.to_excel(writer, sheet_name=group_name,startrow=4)

# %% [markdown]
# #### Merging Aptify & Pearson Data (RHIA)

# %%
RHIA_Schools = pd.read_excel('2023-2024 Q3 RHIA Schools.xlsx')
RHIA_Schools.head()
# Out:
#        ID  AHIMA ID Applicant's Name      Exam Pass Date Certification Status
# 0  294345   2885867   Eliza Sandoval 2024-02-01 07:38:26          RHIA   Fail  \
# 1  293406   1196549   Christina Ball 2024-02-01 08:41:23          RHIA   Pass
# 2  295548   2927718   Ansley Blanton 2024-02-02 07:05:30          RHIA   Pass
# 3  295198   2412652    Debbie Hodges 2024-02-03 08:16:49          RHIA   Fail
# 4  298586   1766547       Robert Lam 2024-02-03 08:22:47          RHIA   Pass
#
#   EPC Code                                        School Name Graduation Date
# 0    HB132  University of Washington Health Informatics an...      2022-06-10  \
# 1    HB152                       Western Governors University      2022-09-14
# 2    HB086                           East Carolina University      2022-05-06
# 3    HB086                           East Carolina University      2007-05-05
# 4    HM015                           Slippery Rock University      2023-05-06
#
#    School Notifications
# ...

# %%
RHIA_School_Scores = pd.merge(RHIA,RHIA_Schools, on='AHIMA ID', how='left')
RHIA_School_Scores.head()
# Out:
#    AHIMA ID              Form  Attempt Number Status_x Exam Date  Domain 1
# 0   2845034  RHIAMAR2024Form2               2     pass  4/9/2024        70  \
# 1   2948153  RHIAMAR2024Form2               1     pass  4/9/2024        57
# 2   2953958  RHIAMAR2024Form2               1     pass  4/9/2024        78
# 3   2847686  RHIAMAR2024Form1               1     pass  4/8/2024        79
# 4   2883451  RHIAMAR2024Form2               1     pass  4/8/2024        74
#
#    Domain 2  Domain 3  Domain 4  Domain 5  Scale Score        ID
# 0        70        70        73        61          305  297101.0  \
# 1        80        77        73        68          308  298798.0
# 2        75        80        73        84          318  301648.0
# 3        95        67        65        63          310  299671.0
# 4        70        67        69        55          302  295815.0
#
#   Applicant's Name      Exam Pass Date Certification Status_y EPC Code
# ...

# %%
RHIA_School_Scores['Total']=np.nan
RHIA_School_Scores.head()
# Out:
#    AHIMA ID              Form  Attempt Number Status_x Exam Date  Domain 1
# 0   2845034  RHIAMAR2024Form2               2     pass  4/9/2024        70  \
# 1   2948153  RHIAMAR2024Form2               1     pass  4/9/2024        57
# 2   2953958  RHIAMAR2024Form2               1     pass  4/9/2024        78
# 3   2847686  RHIAMAR2024Form1               1     pass  4/8/2024        79
# 4   2883451  RHIAMAR2024Form2               1     pass  4/8/2024        74
#
#    Domain 2  Domain 3  Domain 4  Domain 5  ...        ID  Applicant's Name
# 0        70        70        73        61  ...  297101.0     Edith Ramirez  \
# 1        80        77        73        68  ...  298798.0      Megan Rubsam
# 2        75        80        73        84  ...  301648.0     Susan Safford
# 3        95        67        65        63  ...  299671.0   Matthew Shields
# 4        70        67        69        55  ...  295815.0      Joshua Menor
#
#        Exam Pass Date Certification Status_y EPC Code
# ...

# %%
RHIA_School_Scores = RHIA_School_Scores[["Applicant's Name",'Attempt Number','Status_y','Exam Date','Graduation Date','Total','Domain 1','Domain 2','Domain 3','Domain 4','Domain 5','Scale Score','EPC Code','School Name','School Notifications']]
RHIA_School_Scores.head()
# Out:
#   Applicant's Name  Attempt Number Status_y Exam Date Graduation Date  Total
# 0    Edith Ramirez               2     Pass  4/9/2024      2022-05-06    NaN  \
# 1     Megan Rubsam               1     Pass  4/9/2024             NaT    NaN
# 2    Susan Safford               1     Pass  4/9/2024      2020-08-30    NaN
# 3  Matthew Shields               1     Pass  4/8/2024      2022-05-31    NaN
# 4     Joshua Menor               1     Pass  4/8/2024      2023-04-27    NaN
#
#    Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Scale Score EPC Code
# 0        70        70        70        73        61          305    HB100  \
# 1        57        80        77        73        68          308    HB090
# 2        78        75        80        73        84          318    HB148
# 3        79        95        67        65        63          310      817
# 4        74        70        67        69        55          302    HB136
#
# ...

# %%
RHIA_School_Scores = RHIA_School_Scores[["Applicant's Name",'Attempt Number','Status_y','Exam Date','Graduation Date','Total','Domain 1','Domain 2','Domain 3','Domain 4','Domain 5','Scale Score','EPC Code','School Name','School Notifications']]

# %%
RHIA_School_Scores = RHIA_School_Scores.rename(columns={'Status_y': 'Status'})
RHIA_School_Scores.head()
# Out:
#   Applicant's Name  Attempt Number Status Exam Date Graduation Date  Total
# 0    Edith Ramirez               2   Pass  4/9/2024      2022-05-06    NaN  \
# 1     Megan Rubsam               1   Pass  4/9/2024             NaT    NaN
# 2    Susan Safford               1   Pass  4/9/2024      2020-08-30    NaN
# 3  Matthew Shields               1   Pass  4/8/2024      2022-05-31    NaN
# 4     Joshua Menor               1   Pass  4/8/2024      2023-04-27    NaN
#
#    Domain 1  Domain 2  Domain 3  Domain 4  Domain 5  Scale Score EPC Code
# 0        70        70        70        73        61          305    HB100  \
# 1        57        80        77        73        68          308    HB090
# 2        78        75        80        73        84          318    HB148
# 3        79        95        67        65        63          310      817
# 4        74        70        67        69        55          302    HB136
#
#                               School Name  School Notifications
# ...

# %%
RHIA_School_Scores.dtypes
# Out:
# Applicant's Name         object
# Attempt Number            int64
# Status                   object
# Exam Date                object
# Graduation Date          object
# Total                   float64
# Domain 1                  int64
# Domain 2                  int64
# Domain 3                  int64
# Domain 4                  int64
# Domain 5                  int64
# Scale Score               int64
# EPC Code                 object
# School Name              object
# School Notifications    float64
# dtype: object

# %%
groups = RHIA_School_Scores.groupby('EPC Code')


#print('Group Name:', group_name)
#print(group_df)    
with pd.ExcelWriter('RHIA_School_Score_Report_Qtr3_20232024.xlsx') as writer:
    for group_name, group_df in groups:
        group_df.to_excel(writer, sheet_name=group_name,startrow=3)
